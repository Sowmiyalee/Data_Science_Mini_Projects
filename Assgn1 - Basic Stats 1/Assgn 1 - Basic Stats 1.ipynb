# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # ***Question 7***

# %% [markdown]
#  Calculate Mean, Median, Mode, Variance, Standard Deviation, Range &     comment about the values / draw inferences, for the given dataset
# -	For Points,Score,Weigh>
# Find Mean, Median, Mode, Variance, Standard Deviation, and Range and also Comment about the values/ Draw some inferences.

# %%
data = pd.read_csv('/content/Q7.csv')

# %%
data.head()
# Out:
#           Unnamed: 0  Points  Score  Weigh
# 0          Mazda RX4    3.90  2.620  16.46
# 1      Mazda RX4 Wag    3.90  2.875  17.02
# 2         Datsun 710    3.85  2.320  18.61
# 3     Hornet 4 Drive    3.08  3.215  19.44
# 4  Hornet Sportabout    3.15  3.440  17.02

# %%
data.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
print('Mean of Points=', data['Points'].mean())
print('Mean of Score =', data['Score'].mean())
print('Mean of Weight =', data['Weigh'].mean())
# Out:
# Mean of Points= 3.5965625
# Mean of Score = 3.2172500000000004
# Mean of Weight = 17.848750000000003

# %%
print('Median of Points=', data['Points'].median())
print('Median of Score =', data['Score'].median())
print('Median of Weight =', data['Weigh'].median())
# Out:
# Median of Points= 3.6950000000000003
# Median of Score = 3.325
# Median of Weight = 17.71

# %%
print('Variance of Points=', data['Points'].var())
print('Variance of Score =', data['Score'].var())
print('Variance of Weight =', data['Weigh'].var())
# Out:
# Variance of Points= 0.2858813508064516
# Variance of Score = 0.9573789677419354
# Variance of Weight = 3.193166129032258

# %%
print('Variance of Points=', data['Points'].var())
print('Variance of Score =', data['Score'].var())
print('Variance of Weight =', data['Weigh'].var())
# Out:
# Variance of Points= 0.2858813508064516
# Variance of Score = 0.9573789677419354
# Variance of Weight = 3.193166129032258

# %%
print('SD of Points=', data['Points'].std())
print('SD of Score =', data['Score'].std())
print('SD of Weight =', data['Weigh'].std())
# Out:
# SD of Points= 0.5346787360709715
# SD of Score = 0.9784574429896966
# SD of Weight = 1.7869432360968431

# %%
print('Min Value of Points=', data['Points'].min())
print('Min Value of Score =', data['Score'].min())
print('Min Value of Weight =', data['Weigh'].min())
# Out:
# Min Value of Points= 2.76
# Min Value of Score = 1.513
# Min Value of Weight = 14.5

# %%
print('Max Value of Points=', data['Points'].max())
print('Max Value of Score =', data['Score'].max())
print('Max Value of Weight =', data['Weigh'].max())
# Out:
# Max Value of Points= 4.93
# Max Value of Score = 5.424
# Max Value of Weight = 22.9

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['Points'])
# Out:
# (array([3., 8., 2., 2., 4., 6., 5., 1., 0., 1.]),
#  array([2.76 , 2.977, 3.194, 3.411, 3.628, 3.845, 4.062, 4.279, 4.496,
#         4.713, 4.93 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.distplot(data['Points'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Points', ylabel='Density'>

# %%
sns.distplot(data['Score'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Score', ylabel='Density'>

# %%
sns.distplot(data['Weigh'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weigh', ylabel='Density'>

# %%
data.rename(columns= {'Unnamed: 0' : 'Car Name'}, inplace=True)
data.head(2)
# Out:
#         Car Name  Points  Score  Weigh
# 0      Mazda RX4     3.9  2.620  16.46
# 1  Mazda RX4 Wag     3.9  2.875  17.02

# %%
plt.boxplot(x='Points', data =data)
plt.xlabel ('Points')
# Out:
# Text(0.5, 0, 'Points')

# %%
plt.boxplot(x='Score', data = data)
plt.xlabel('Score')
# Out:
# Text(0.5, 0, 'Score')

# %%
plt.boxplot(x='Weigh', data = data)
plt.xlabel('Weigh')
# Out:
# Text(0.5, 0, 'Weigh')

# %%
plt.figure(figsize=(15,10))
plt.barh(data['Car Name'], data['Points'], data=data)   #barh for horizontal graph
plt.yticks(fontsize=15)
plt.xlabel('Points')
plt.ylabel('Cars')
# Out:
# Text(0, 0.5, 'Cars')

# %%
plt.figure(figsize=(15,10))
plt.barh(data['Car Name'], data['Score'], data=data)   #barh for horizontal graph
plt.yticks(fontsize=15)
plt.xlabel('Score')
plt.ylabel('Cars')
# Out:
# Text(0, 0.5, 'Cars')

# %%
plt.figure(figsize=(15,10))
plt.barh(data['Car Name'], data['Weigh'], data=data)   #barh for horizontal graph
plt.yticks(fontsize=15)
plt.xlabel('Weight')
plt.ylabel('Cars')
# Out:
# Text(0, 0.5, 'Cars')

# %% [markdown]
# # ***Question 8***

# %% [markdown]
# Calculate Expected Value for the problem below
#
# a)	The weights (X) of patients at a clinic (in pounds), are
# 108, 110, 123, 134, 135, 145, 167, 187, 199
# Assume one of the patients is chosen at random. What is the Expected Value of the Weight of that patient?

# %%
import numpy as np

def expected_value(values, weights):
    values = np.asarray(values)
    weights = np.asarray(weights)
    return (values * weights).sum() / weights.sum()

# %%
X = [108, 110, 123, 134, 135, 145, 167, 187, 199]
probability = [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9]

# %%
expected_value(X,probability)
# Out:
# 145.33333333333331

# %% [markdown]
# # ***Question 9***

# %% [markdown]
# Calculate Skewness, Kurtosis & draw inferences on the following data
# Cars speed and distance

# %%
q9a=pd.read_csv('/content/Q9_a.csv', index_col=0)
q9a.head()
# Out:
#        speed  dist
# Index
# 1          4     2
# 2          4    10
# 3          7     4
# 4          7    22
# 5          8    16

# %%
q9a.speed.skew()
# Out:
# -0.11750986144663393

# %%
q9a.speed.kurt()
# Out:
# -0.5089944204057617

# %%
print('Skewness of Speed = ',np.round(q9a.speed.skew(),2), 'and', 'Kurtosis of Speed = ', np.round(q9a.speed.kurt(),2))
# Out:
# Skewness of Speed =  -0.12 and Kurtosis of Speed =  -0.51

# %%
q9a.dist.skew()
# Out:
# 0.8068949601674215

# %%
q9a.dist.kurt()
# Out:
# 0.4050525816795765

# %%
print('Skewness of Speed = ',np.round(q9a.dist.skew(),2), 'and', 'Kurtosis of Speed = ', np.round(q9a.dist.kurt(),2))
# Out:
# Skewness of Speed =  0.81 and Kurtosis of Speed =  0.41

# %%
sns.distplot(q9a['speed'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='speed', ylabel='Density'>

# %%
sns.distplot(q9a['dist'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='dist', ylabel='Density'>

# %%
q9b=pd.read_csv('/content/Q9_b.csv', index_col=0)
q9b.head()
# Out:
#            SP         WT
# 1  104.185353  28.762059
# 2  105.461264  30.466833
# 3  105.461264  30.193597
# 4  113.461264  30.632114
# 5  104.461264  29.889149

# %%
print('Skewness of SP = ',np.round(q9b.SP.skew(),3), 'and', 'Kurtosis of SP = ', np.round(q9b.SP.kurt(),3))
# Out:
# Skewness of SP =  1.611 and Kurtosis of SP =  2.977

# %%
print('Skewness of WT = ',np.round(q9b.WT.skew(),3), 'and', 'Kurtosis of WT = ', np.round(q9b.WT.kurt(),3))
# Out:
# Skewness of WT =  -0.615 and Kurtosis of WT =  0.95

# %%
sns.distplot(q9b['SP'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SP', ylabel='Density'>

# %%
sns.distplot(q9b['WT'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='WT', ylabel='Density'>

# %% [markdown]
# # ***Question 11***

# %% [markdown]
# Suppose we want to estimate the average weight of an adult male in    Mexico. We draw a random sample of 2,000 men from a population of 3,000,000 men and weigh them. We find that the average person in our sample weighs 200 pounds, and the standard deviation of the sample is 30 pounds. Calculate 94%,98%,96% confidence interval?

# %%
from scipy import stats

conf94 = stats.norm.interval(alpha=0.94, loc=200, scale = 30/np.sqrt(2000))
conf94
# Out:
# (198.738325292158, 201.261674707842)

# %%
conf96 = stats.norm.interval(alpha=0.96, loc=200, scale = 30/np.sqrt(2000))
conf96
# Out:
# (198.62230334813333, 201.37769665186667)

# %%
conf98 = stats.norm.interval(alpha=0.96, loc=200, scale = 30/np.sqrt(2000))
conf98
# Out:
# (198.62230334813333, 201.37769665186667)

# %% [markdown]
# #***Question 12***

# %% [markdown]
# Below are the scores obtained by a student in tests
# 34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56

# %%
Marks = [34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56]

# %%
Mrk= pd.DataFrame(data = Marks, dtype=float)

# %%
Mrk.head()
# Out:
#       0
# 0  34.0
# 1  36.0
# 2  36.0
# 3  38.0
# 4  38.0

# %%
Mrk.describe()
# Out:
#                0
# count  18.000000
# mean   41.000000
# std     5.052664
# min    34.000000
# 25%    38.250000
# 50%    40.500000
# 75%    41.750000
# max    56.000000

# %%
print ('Variance in Marks is', Mrk.var())
# Out:
# Variance in Marks is 0    25.529412
# dtype: float64

# %%
print ('SD of Marks is', Mrk.std())
# Out:
# SD of Marks is 0    5.052664
# dtype: float64

# %%
sns.boxplot(data=Mrk)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # ***Question 20***

# %% [markdown]
# Calculate probability from the given dataset for the below cases
#
# Data _set: Cars.csv
# Calculate the probability of MPG  of Cars for the below cases.
#        MPG <- Cars$MPG
#
# a.	P(MPG>38)
#
# b.	P(MPG<40)
#
# c.    P (20<MPG<50)

# %%
q20 = pd.read_csv('/content/Cars.csv')

# %%
q20.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
q20.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
P_grtr_than_38 = 1- stats.norm.cdf(38,loc = q20.MPG.mean(), scale = q20.MPG.std())
P_grtr_than_38
# Out:
# 0.34759392515827137

# %%
P_less_than_40 = stats.norm.cdf(40,loc = q20.MPG.mean(), scale = q20.MPG.std())
P_less_than_40
# Out:
# 0.7293498762151609

# %%
P_grtr_than_20 = 1- stats.norm.cdf(20,loc = q20.MPG.mean(), scale = q20.MPG.std())
P_grtr_than_20
# Out:
# 0.9428762236788408

# %%
P_less_than_50 = stats.norm.cdf(50,loc = q20.MPG.mean(), scale = q20.MPG.std())
P_less_than_50
# Out:
# 0.9559926932893639

# %%
P_btw_20and50 = P_less_than_50 - P_grtr_than_20
P_btw_20and50
# Out:
# 0.01311646961052304

# %% [markdown]
# # ***Question 21***

# %% [markdown]
# Check whether the data follows normal distribution
#
# a)	Check whether the MPG of Cars follows Normal Distribution
#         Dataset: Cars.csv

# %%
q21a=pd.read_csv('/content/Cars.csv')

# %%
sns.distplot(q21a['MPG'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MPG', ylabel='Density'>

# %%
plt.hist(x='MPG', bins=10, edgecolor ='Red', data = q21a)
# Out:
# (array([ 1.,  6., 10.,  4., 10., 15., 17.,  8.,  5.,  5.]),
#  array([12.10126289, 16.26120474, 20.42114659, 24.58108844, 28.74103029,
#         32.90097213, 37.06091398, 41.22085583, 45.38079768, 49.54073953,
#         53.70068138]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x='MPG', data=q21a, showmeans= True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7efbb10aca90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7efbb1036070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7efbb10ac7c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7efbb1036610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7efbb1036bb0>],
#  'means': [<matplotlib.lines.Line2D at 0x7efbb10368e0>]}

# %% [markdown]
# b)	Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution.
#        Dataset: wc-at.csv

# %%
q21b=pd.read_csv('/content/wc-at.csv')

# %%
q21b.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
sns.distplot(q21b['Waist'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Waist', ylabel='Density'>

# %%
plt.boxplot(x='Waist', data=q21b, showmeans= True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7efbb0f78e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7efbb0f87460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7efbb0f78cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7efbb0f87a00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7efbb0f87fa0>],
#  'means': [<matplotlib.lines.Line2D at 0x7efbb0f87cd0>]}

# %%
sns.distplot(q21b['AT'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AT', ylabel='Density'>

# %%
plt.boxplot(x='AT', data=q21b, showmeans= True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7efbb0ec8eb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7efbb0ed74c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7efbb0ec8d30>],
#  'medians': [<matplotlib.lines.Line2D at 0x7efbb0ed7a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7efbb0ee6040>],
#  'means': [<matplotlib.lines.Line2D at 0x7efbb0ed7d30>]}

# %% [markdown]
# # ***Question 22***

# %% [markdown]
# Calculate the Z scores of  90% confidence interval,94% confidence interval, 60% confidence interval

# %%
print('Z Score for 90% confidence interval = ', stats.norm.ppf(0.05))   #10% div by 2 = 5% = 0.05
# Out:
# Z Score for 90% confidence interval =  -1.6448536269514729

# %%
print('Z Score for 94% confidence interval = ', stats.norm.ppf(0.03))   #6% div by 2 = 3% = 0.03
# Out:
# Z Score for 94% confidence interval =  -1.880793608151251

# %%
print('Z Score for 60% confidence interval = ', stats.norm.ppf(0.2))  #40% div by 2 = 20% = 0.2
# Out:
# Z Score for 90% confidence interval =  -0.8416212335729142

# %% [markdown]
# # ***Question 23***

# %% [markdown]
# Calculate the t scores of 95% confidence interval, 96% confidence interval, 99% confidence interval for sample size of 25

# %%
print('T Score for 95% confidence interval = ', stats.t.ppf(0.025, df=24))   #5% div by 2 = 0.25% = 0.025
# Out:
# T Score for 95% confidence interval =  -2.063898561628021

# %%
print('T Score for 96% confidence interval = ', stats.t.ppf(0.03, df=24))   #6% div by 2 = 0.3% = 0.03
# Out:
# T Score for 96% confidence interval =  -1.9739942888471331

# %%
print('T Score for 99% confidence interval = ', stats.t.ppf(0.005, df=24))   #1% div by 2 = 0.5% = 0.005
# Out:
# T Score for 99% confidence interval =  -2.796939504772805

# %% [markdown]
# # **Question 23**

# %% [markdown]
#  A Government company claims that an average light bulb lasts 270 days. A researcher randomly selects 18 bulbs for testing. The sampled bulbs last an average of 260 days, with a standard deviation of 90 days. If the CEO's claim were true, what is the probability that 18 randomly selected bulbs would have an average life of no more than 260 days

# %%
# t_score = (x - pop mean) / (sample standard daviation / square root of sample size)

# %%
t_score= ((260-270)/90*np.sqrt(18))
t_score
# Out:
# -0.4714045207910316

# %%
stats.t.cdf(t_score, df = 17)
# Out:
# 0.32167253567098364

# %%
print ('Probability of 18 randomly selected bulbs will have an avg life of no more than 260 days is', np.round(0.32167253567098364*100,2), '%')
# Out:
# Probability of 18 randomly selected bulbs will have an avg life of no more than 260 days is 32.17 %
