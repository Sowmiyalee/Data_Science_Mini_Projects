# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as stats
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Question 1**

# %% [markdown]
# Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2
#
# Name of company	\ Measure X
#
# ---
#
#
# Allied Signal	24.23%
#
# ---
#
#
# Bankers Trust	25.53%
#
# ---
#
#
# General Mills	25.41%
#
# ---
#
#
# ITT Industries	24.14%
#
# ---
#
#
# J.P.Morgan & Co.	29.62%
#
# ---
#
#
# Lehman Brothers	28.25%
#
# ---
#
#
# Marriott	25.81%
#
# ---
#
#
# MCI	24.39%
#
# ---
#
#
# Merrill Lynch	40.26%
#
# ---
#
#
# Microsoft	32.95%
#
# ---
#
#
# Morgan Stanley	91.36%
#
# ---
#
#
# Sun Microsystems	25.99%
#
# ---
#
#
# Travelers	39.42%
#
# ---
#
#
# US Airways	26.71%
#
# ---
#
#
# Warner-Lambert	35.00%

# %%
measure_x = [24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00]
name_of_company = ['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']
plt.figure (figsize =(10,10))
plt.pie(measure_x, labels= name_of_company, autopct= '%1.1f%%', shadow = True)   # To add percentages to each of the constitutents of the pie chart, we add in the line, autopct='%1.1f%%', to the plt. pie() function. This formats the percentage to the tenth place. If you want to format the percentage to the hundredths place, you would use the statement, autopct='%1.2f%
plt.title ('Name of Company with respect to X')
plt.show()

# %%
plt.figure(figsize=(10,8))
bar = sns.barplot(x=name_of_company, y=measure_x, edgecolor='Black')
plt.xticks (rotation = 90, fontsize='12', fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(measure_x)
plt.show()
measure_x= pd.Series(measure_x)
Q1 = np.quantile(measure_x,0.25)
Q3 = np.quantile(measure_x,0.75)
med = np.median(measure_x) 
IQR = Q3 - Q1
upper_whisker = Q3 + (1.5*IQR)
lower_whisker = Q1 - (1.5*IQR)
outliers = measure_x[(measure_x >= upper_whisker)]

print('First Quartile=', Q1)
print('Median=', med)
print('Third Quartile=', Q3) 
print('Inter Quartile Range=', IQR) 
print('Lower Whisker=', lower_whisker) 
print('Upper Whisker=', upper_whisker)
print('The outlier in the boxplot:',outliers)

print(measure_x.describe())
print("Variance=",measure_x.var())
# Out:
# First Quartile= 25.47
# Median= 26.71
# Third Quartile= 33.975
# Inter Quartile Range= 8.505000000000003
# Lower Whisker= 12.712499999999995
# Upper Whisker= 46.7325
# The outlier in the boxplot: 10    91.36
# dtype: float64
# count    15.000000
# mean     33.271333
# std      16.945401
# min      24.140000
# 25%      25.470000
# 50%      26.710000
# 75%      33.975000
# max      91.360000
# dtype: float64
# Variance= 287.1466123809524
