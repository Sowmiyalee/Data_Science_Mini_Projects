# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/gas_turbines.csv')
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %% [markdown]
# ## EDA

# %%
data.shape
# Out:
# (15039, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
data.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
data.isnull()
# Out:
#           AT     AP     AH   AFDP   GTEP    TIT    TAT    TEY    CDP     CO  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 15034  False  False  False  False  False  False  False  False  False  False
# 15035  False  False  False  False  False  False  False  False  False  False
# 15036  False  False  False  False  False  False  False  False  False  False
# 15037  False  False  False  False  False  False  False  False  False  False
# 15038  False  False  False  False  False  False  False  False  False  False
#
#          NOX
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 15034  False
# 15035  False
# 15036  False
# 15037  False
# 15038  False
#
# [15039 rows x 11 columns]

# %%
data.isnull().sum()
# Out:
# AT      0
# AP      0
# AH      0
# AFDP    0
# GTEP    0
# TIT     0
# TAT     0
# TEY     0
# CDP     0
# CO      0
# NOX     0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(data)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import matplotlib.pyplot as plt
sns.factorplot ('TEY', data=data, kind='box', size=5)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.plot(kind='density', subplots = True, layout = (3,4), figsize=(13,20), sharex = False, sharey = False)
plt.show()

# %%
data.plot(kind='box', subplots = True, layout = (4,3), figsize = (13,20), sharex = False, sharey = False)
plt.show()

# %% [markdown]
# ### Finding corelation between variables

# %%
data.corr()
# Out:
#             AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# AT    1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067  0.338569
# AP   -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650 -0.223479
# AH   -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781  0.010859
# AFDP -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254 -0.571541
# GTEP -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526 -0.756884
# TIT   0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000 -0.357320
# TAT   0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320  1.000000
# TEY  -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587 -0.720356
# CDP  -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238 -0.744740
# CO   -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272  0.063404
# NOX  -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636  0.009888
#
#            TEY       CDP        CO       NOX
# AT   -0.207495 -0.100705 -0.088588 -0.600006
# AP    0.146939  0.131198  0.041614  0.256744
# AH   -0.110272 -0.182010  0.165505  0.143061
# AFDP  0.717995  0.727152 -0.334207 -0.037299
# GTEP  0.977042  0.993784 -0.508259 -0.208496
# TIT   0.891587  0.887238 -0.688272 -0.231636
# TAT  -0.720356 -0.744740  0.063404  0.009888
# TEY   1.000000  0.988473 -0.541751 -0.102631
# CDP   0.988473  1.000000 -0.520783 -0.169103
# CO   -0.541751 -0.520783  1.000000  0.316743
# NOX  -0.102631 -0.169103  0.316743  1.000000

# %%
sns.heatmap(data.corr(), annot = True)

# %%
f, axes = plt.subplots(5,2, figsize=(15,20))

sns.regplot(x = 'TEY', y = 'AT', data = data, ax = axes[0,0], color = 'g', scatter_kws={'alpha':0.6})
axes[0,0].set_xlabel('TEY', fontsize = 14)
axes[0,0].set_ylabel('AT', fontsize=14)
axes[0,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'AP', data = data, ax = axes[0,1], color = 'y',scatter_kws={'alpha':0.6})
axes[0,1].set_xlabel('TEY', fontsize = 14)
axes[0,1].set_ylabel('AP', fontsize=14)
axes[0,1].yaxis.set_label_position("right")
axes[0,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'AH', data = data, ax = axes[1,0], color = 'g',scatter_kws={'alpha':0.6})
axes[1,0].set_xlabel('TEY', fontsize = 14)
axes[1,0].set_ylabel('AH', fontsize=14)
axes[1,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'AFDP', data = data, ax = axes[1,1], color = 'y',scatter_kws={'alpha':0.6})
axes[1,1].set_xlabel('TEY', fontsize = 14)
axes[1,1].set_ylabel('AFDP', fontsize=14)
axes[1,1].yaxis.set_label_position("right")
axes[1,1].yaxis.tick_right()

sns.regplot(x = 'TEY', y = 'GTEP', data = data, ax = axes[2,0], color = 'g',scatter_kws={'alpha':0.6})
axes[2,0].set_xlabel('TEY', fontsize = 14)
axes[2,0].set_ylabel('GTEP', fontsize=14)
axes[2,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'TIT', data = data, ax = axes[2,1], color = 'y',scatter_kws={'alpha':0.6})
axes[2,1].set_xlabel('TEY', fontsize = 14)
axes[2,1].set_ylabel('TIT', fontsize=14)
axes[2,1].yaxis.set_label_position("right")
axes[2,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'TAT', data = data, ax = axes[3,0], color = 'g',scatter_kws={'alpha':0.6})
axes[3,0].set_xlabel('TEY', fontsize = 14)
axes[3,0].set_ylabel('TAT', fontsize=14)
axes[3,0].yaxis.tick_left()


sns.regplot(x = 'TEY', y = 'CDP', data = data, ax = axes[3,1], color = 'y',scatter_kws={'alpha':0.6})
axes[3,1].set_xlabel('TEY', fontsize = 14)
axes[3,1].set_ylabel('CDP', fontsize=14)
axes[3,1].yaxis.set_label_position("right")
axes[3,1].yaxis.tick_right()


sns.regplot(x = 'TEY', y = 'CO', data = data, ax = axes[4,0], color = 'g',scatter_kws={'alpha':0.6})
axes[4,0].set_xlabel('TEY', fontsize = 14)
axes[4,0].set_ylabel('CO', fontsize=14)
axes[4,0].yaxis.set_label_position("right")


sns.regplot(x = 'TEY', y = 'NOX', data = data, ax = axes[4,1], color = 'y',scatter_kws={'alpha':0.6})
axes[4,1].set_xlabel('TEY', fontsize = 14)
axes[4,1].set_ylabel('NOX', fontsize=14)
axes[4,1].yaxis.set_label_position("right")
axes[4,1].yaxis.tick_right()

plt.show()

# it shows that AFDP, GTEP, TIT, TAT, CDP has regression linw

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression

X = data.drop(['TEY'], axis = 1)
y = data.iloc[:,7]

# feature selection
def select_features(X_train, y_train, X_test):
    # configure to select all features
    fs = SelectKBest(score_func=mutual_info_regression, k='all')
    # learn relationship from training data
    fs.fit(X_train, y_train)
    # transform train input data
    X_train_fs = fs.transform(X_train)
    # transform test input data
    X_test_fs = fs.transform(X_test)
    return X_train_fs, X_test_fs, fs

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

# what are scores for the features
for i in range(len(fs.scores_)):
    print('Feature %d: %f' % (i, fs.scores_[i]))
    
# plot the scores
fig, ax = plt.subplots(figsize=(10, 6))
plt.bar([i for i in range(len(fs.scores_))], fs.scores_)
plt.show()
# Out:
# Feature 0: 0.402998
# Feature 1: 0.148447
# Feature 2: 0.091141
# Feature 3: 0.656749
# Feature 4: 1.590982
# Feature 5: 1.303366
# Feature 6: 0.910906
# Feature 7: 1.711025
# Feature 8: 0.506026
# Feature 9: 0.304033

# %% [markdown]
# ## Model Building

# %%
X = data.drop(['TEY','AT','AP','AH','CO','NOX'], axis = 1)
y = data.iloc[:,7]
y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
# Standardizing data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

scaler.fit(X)
# Out:
# StandardScaler()

# %%
y = StandardScaler().fit_transform(y.values.reshape(len(y),1))[:,0]
y
# Out:
# array([-1.23117246, -1.22990897, -1.23054071, ..., -1.5160891 ,
#        -1.48134317, -1.42827666])

# %%
scaled_features=scaler.transform(X)
scaled_features
# Out:
# array([[-0.92123188, -1.37910125, -1.48837592,  0.58524028, -1.35733078],
#        [-0.92149498, -1.36352783, -1.4823253 ,  0.58524028, -1.36367619],
#        [-0.94438456, -1.35130868, -1.47627469,  0.56871459, -1.36095673],
#        ...,
#        [-0.95148822, -1.41096688, -2.78925732, -1.02664984, -1.46792219],
#        [-0.98884822, -1.44762432, -2.4564737 , -0.52833681, -1.42259784],
#        [-1.01660512, -1.46463529, -2.05108275,  0.05768949, -1.37727349]])

# %%
data_head=pd.DataFrame(scaled_features,columns=X.columns)
data_head
# Out:
#            AFDP      GTEP       TIT       TAT       CDP
# 0     -0.921232 -1.379101 -1.488376  0.585240 -1.357331
# 1     -0.921495 -1.363528 -1.482325  0.585240 -1.363676
# 2     -0.944385 -1.351309 -1.476275  0.568715 -1.360957
# 3     -0.946884 -1.348194 -1.464173  0.583969 -1.356424
# 4     -0.924389 -1.354663 -1.458123  0.582698 -1.350985
# ...         ...       ...       ...       ...       ...
# 15034 -0.865850 -1.498657 -2.063184  0.103453 -1.543161
# 15035 -0.913470 -1.438759 -2.268905 -0.276638 -1.513247
# 15036 -0.951488 -1.410967 -2.789257 -1.026650 -1.467922
# 15037 -0.988848 -1.447624 -2.456474 -0.528337 -1.422598
# 15038 -1.016605 -1.464635 -2.051083  0.057689 -1.377273
#
# [15039 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# create model
model = Sequential()
model.add(Dense(10, input_dim=5, kernel_initializer='he_uniform', activation='tanh'))
model.add(Dense(6, kernel_initializer='he_uniform', activation='tanh'))
model.add(Dense(1, kernel_initializer='he_uniform', activation='linear'))


# Compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse','mae'])

# Fit the model
fit = model.fit(x_train,y_train,validation_split=0.33, epochs=70, batch_size=40)
# Out:
# Epoch 1/70
# 177/177 [==============================] - 2s 7ms/step - loss: 1.2875 - mse: 1.2875 - mae: 0.8564 - val_loss: 0.9959 - val_mse: 0.9959 - val_mae: 0.7134
# Epoch 2/70
# 177/177 [==============================] - 1s 4ms/step - loss: 0.9927 - mse: 0.9927 - mae: 0.7026 - val_loss: 0.9969 - val_mse: 0.9969 - val_mae: 0.7015
# Epoch 3/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9912 - mse: 0.9912 - mae: 0.7021 - val_loss: 1.0000 - val_mse: 1.0000 - val_mae: 0.7331
# Epoch 4/70
# 177/177 [==============================] - 0s 3ms/step - loss: 0.9921 - mse: 0.9921 - mae: 0.7032 - val_loss: 0.9988 - val_mse: 0.9988 - val_mae: 0.7018
# Epoch 5/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9930 - mse: 0.9930 - mae: 0.7035 - val_loss: 0.9975 - val_mse: 0.9975 - val_mae: 0.7009
# Epoch 6/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9933 - mse: 0.9933 - mae: 0.7026 - val_loss: 1.0016 - val_mse: 1.0016 - val_mae: 0.7075
# Epoch 7/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9924 - mse: 0.9924 - mae: 0.7029 - val_loss: 0.9978 - val_mse: 0.9978 - val_mae: 0.7250
# Epoch 8/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9935 - mse: 0.9935 - mae: 0.7072 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7090
# Epoch 9/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9929 - mse: 0.9929 - mae: 0.7028 - val_loss: 0.9984 - val_mse: 0.9984 - val_mae: 0.7012
# Epoch 10/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9932 - mse: 0.9932 - mae: 0.7021 - val_loss: 0.9968 - val_mse: 0.9968 - val_mae: 0.7016
# Epoch 11/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9936 - mse: 0.9936 - mae: 0.7070 - val_loss: 1.0044 - val_mse: 1.0044 - val_mae: 0.7129
# Epoch 12/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9936 - mse: 0.9936 - mae: 0.7034 - val_loss: 0.9998 - val_mse: 0.9998 - val_mae: 0.7038
# Epoch 13/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9935 - mse: 0.9935 - mae: 0.7051 - val_loss: 0.9973 - val_mse: 0.9973 - val_mae: 0.7227
# Epoch 14/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9932 - mse: 0.9932 - mae: 0.7041 - val_loss: 1.0002 - val_mse: 1.0002 - val_mae: 0.7046
# Epoch 15/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9927 - mse: 0.9927 - mae: 0.7042 - val_loss: 0.9957 - val_mse: 0.9957 - val_mae: 0.7110
# Epoch 16/70
# 177/177 [==============================] - 0s 3ms/step - loss: 0.9925 - mse: 0.9925 - mae: 0.7032 - val_loss: 0.9974 - val_mse: 0.9974 - val_mae: 0.7010
# Epoch 17/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9928 - mse: 0.9928 - mae: 0.7034 - val_loss: 0.9961 - val_mse: 0.9961 - val_mae: 0.7154
# Epoch 18/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9934 - mse: 0.9934 - mae: 0.7064 - val_loss: 0.9989 - val_mse: 0.9989 - val_mae: 0.7020
# Epoch 19/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9928 - mse: 0.9928 - mae: 0.7071 - val_loss: 0.9963 - val_mse: 0.9963 - val_mae: 0.7166
# Epoch 20/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9933 - mse: 0.9933 - mae: 0.7046 - val_loss: 1.0011 - val_mse: 1.0011 - val_mae: 0.7064
# Epoch 21/70
# 177/177 [==============================] - 1s 4ms/step - loss: 0.9935 - mse: 0.9935 - mae: 0.7049 - val_loss: 0.9967 - val_mse: 0.9967 - val_mae: 0.7019
# Epoch 22/70
# 177/177 [==============================] - 1s 6ms/step - loss: 0.9933 - mse: 0.9933 - mae: 0.7060 - val_loss: 1.0015 - val_mse: 1.0015 - val_mae: 0.7071
# Epoch 23/70
# 177/177 [==============================] - 1s 6ms/step - loss: 0.9936 - mse: 0.9936 - mae: 0.7051 - val_loss: 1.0017 - val_mse: 1.0017 - val_mae: 0.7076
# Epoch 24/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9926 - mse: 0.9926 - mae: 0.7043 - val_loss: 1.0024 - val_mse: 1.0024 - val_mae: 0.7090
# Epoch 25/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9926 - mse: 0.9926 - mae: 0.7033 - val_loss: 1.0028 - val_mse: 1.0028 - val_mae: 0.7098
# Epoch 26/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9925 - mse: 0.9925 - mae: 0.7034 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7098
# Epoch 27/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9933 - mse: 0.9933 - mae: 0.7031 - val_loss: 0.9968 - val_mse: 0.9968 - val_mae: 0.7016
# Epoch 28/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9947 - mse: 0.9947 - mae: 0.7042 - val_loss: 0.9970 - val_mse: 0.9970 - val_mae: 0.7211
# Epoch 29/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9922 - mse: 0.9922 - mae: 0.7069 - val_loss: 0.9962 - val_mse: 0.9962 - val_mae: 0.7160
# Epoch 30/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9947 - mse: 0.9947 - mae: 0.7105 - val_loss: 0.9970 - val_mse: 0.9970 - val_mae: 0.7015
# Epoch 31/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9945 - mse: 0.9945 - mae: 0.7049 - val_loss: 0.9958 - val_mse: 0.9958 - val_mae: 0.7051
# Epoch 32/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9934 - mse: 0.9934 - mae: 0.7044 - val_loss: 0.9960 - val_mse: 0.9960 - val_mae: 0.7039
# Epoch 33/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9934 - mse: 0.9934 - mae: 0.7033 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7102
# Epoch 34/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9933 - mse: 0.9933 - mae: 0.7056 - val_loss: 0.9960 - val_mse: 0.9960 - val_mae: 0.7145
# Epoch 35/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9924 - mse: 0.9924 - mae: 0.7082 - val_loss: 1.0126 - val_mse: 1.0126 - val_mae: 0.7280
# Epoch 36/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9935 - mse: 0.9935 - mae: 0.7051 - val_loss: 0.9964 - val_mse: 0.9964 - val_mae: 0.7025
# Epoch 37/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9940 - mse: 0.9940 - mae: 0.7063 - val_loss: 0.9985 - val_mse: 0.9985 - val_mae: 0.7013
# Epoch 38/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9929 - mse: 0.9929 - mae: 0.7015 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7064
# Epoch 39/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9928 - mse: 0.9928 - mae: 0.7044 - val_loss: 0.9996 - val_mse: 0.9996 - val_mae: 0.7034
# Epoch 40/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9922 - mse: 0.9922 - mae: 0.7040 - val_loss: 0.9968 - val_mse: 0.9968 - val_mae: 0.7017
# Epoch 41/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9927 - mse: 0.9927 - mae: 0.7033 - val_loss: 1.0008 - val_mse: 1.0008 - val_mae: 0.7059
# Epoch 42/70
# 177/177 [==============================] - 1s 5ms/step - loss: 0.9928 - mse: 0.9928 - mae: 0.7006 - val_loss: 0.9961 - val_mse: 0.9961 - val_mae: 0.7157
# Epoch 43/70
# 177/177 [==============================] - 1s 5ms/step - loss: 0.9921 - mse: 0.9921 - mae: 0.7055 - val_loss: 1.0080 - val_mse: 1.0080 - val_mae: 0.7195
# Epoch 44/70
# 177/177 [==============================] - 1s 5ms/step - loss: 0.9929 - mse: 0.9929 - mae: 0.7039 - val_loss: 0.9971 - val_mse: 0.9971 - val_mae: 0.7012
# Epoch 45/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9926 - mse: 0.9926 - mae: 0.7031 - val_loss: 0.9980 - val_mse: 0.9980 - val_mae: 0.7008
# Epoch 46/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9926 - mse: 0.9926 - mae: 0.7047 - val_loss: 0.9973 - val_mse: 0.9973 - val_mae: 0.7010
# Epoch 47/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9944 - mse: 0.9944 - mae: 0.7041 - val_loss: 0.9958 - val_mse: 0.9958 - val_mae: 0.7048
# Epoch 48/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9934 - mse: 0.9934 - mae: 0.7038 - val_loss: 0.9962 - val_mse: 0.9962 - val_mae: 0.7029
# Epoch 49/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9923 - mse: 0.9923 - mae: 0.7035 - val_loss: 0.9957 - val_mse: 0.9957 - val_mae: 0.7112
# Epoch 50/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9922 - mse: 0.9922 - mae: 0.7020 - val_loss: 0.9967 - val_mse: 0.9967 - val_mae: 0.7019
# Epoch 51/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9920 - mse: 0.9920 - mae: 0.7040 - val_loss: 0.9992 - val_mse: 0.9992 - val_mae: 0.7025
# Epoch 52/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9922 - mse: 0.9922 - mae: 0.7018 - val_loss: 0.9974 - val_mse: 0.9974 - val_mae: 0.7009
# Epoch 53/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9932 - mse: 0.9932 - mae: 0.7018 - val_loss: 0.9957 - val_mse: 0.9957 - val_mae: 0.7053
# Epoch 54/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9931 - mse: 0.9931 - mae: 0.7030 - val_loss: 0.9958 - val_mse: 0.9958 - val_mae: 0.7051
# Epoch 55/70
# 177/177 [==============================] - 1s 4ms/step - loss: 0.9924 - mse: 0.9924 - mae: 0.7017 - val_loss: 0.9959 - val_mse: 0.9959 - val_mae: 0.7042
# Epoch 56/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9922 - mse: 0.9922 - mae: 0.7026 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7069
# Epoch 57/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9927 - mse: 0.9927 - mae: 0.7059 - val_loss: 0.9957 - val_mse: 0.9957 - val_mae: 0.7105
# Epoch 58/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9925 - mse: 0.9925 - mae: 0.7006 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7093
# Epoch 59/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9920 - mse: 0.9920 - mae: 0.7016 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7066
# Epoch 60/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9924 - mse: 0.9924 - mae: 0.7014 - val_loss: 0.9985 - val_mse: 0.9985 - val_mae: 0.7013
# Epoch 61/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9925 - mse: 0.9925 - mae: 0.7014 - val_loss: 0.9982 - val_mse: 0.9982 - val_mae: 0.7009
# Epoch 62/70
# 177/177 [==============================] - 1s 5ms/step - loss: 0.9916 - mse: 0.9916 - mae: 0.7037 - val_loss: 0.9966 - val_mse: 0.9966 - val_mae: 0.7021
# Epoch 63/70
# 177/177 [==============================] - 1s 5ms/step - loss: 0.9923 - mse: 0.9923 - mae: 0.7022 - val_loss: 0.9999 - val_mse: 0.9999 - val_mae: 0.7039
# Epoch 64/70
# 177/177 [==============================] - 1s 5ms/step - loss: 0.9927 - mse: 0.9927 - mae: 0.7045 - val_loss: 0.9985 - val_mse: 0.9985 - val_mae: 0.7012
# Epoch 65/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9932 - mse: 0.9932 - mae: 0.7030 - val_loss: 0.9974 - val_mse: 0.9974 - val_mae: 0.7010
# Epoch 66/70
# 177/177 [==============================] - 0s 3ms/step - loss: 0.9923 - mse: 0.9923 - mae: 0.7015 - val_loss: 0.9966 - val_mse: 0.9966 - val_mae: 0.7021
# Epoch 67/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9925 - mse: 0.9925 - mae: 0.7008 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7066
# Epoch 68/70
# 177/177 [==============================] - 0s 3ms/step - loss: 0.9928 - mse: 0.9928 - mae: 0.7007 - val_loss: 0.9959 - val_mse: 0.9959 - val_mae: 0.7041
# Epoch 69/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9919 - mse: 0.9919 - mae: 0.7017 - val_loss: 0.9960 - val_mse: 0.9960 - val_mae: 0.7037
# Epoch 70/70
# 177/177 [==============================] - 1s 3ms/step - loss: 0.9931 - mse: 0.9931 - mae: 0.7036 - val_loss: 0.9956 - val_mse: 0.9956 - val_mae: 0.7082

# %%
scores = model.evaluate(X, y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 470/470 [==============================] - 1s 2ms/step - loss: 1.0005 - mse: 1.0005 - mae: 0.7119
# mse: 100.05%

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 10)                60
#
#  dense_16 (Dense)            (None, 6)                 66
#
#  dense_17 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 133
# Trainable params: 133
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Evaluation

# %%
print(fit.history.keys())
# Out:
# dict_keys(['loss', 'mse', 'mae', 'val_loss', 'val_mse', 'val_mae'])

# %%
fit_df = pd.DataFrame(fit.history)
fit_df["epoch"]=fit.epoch
fit_df.tail()
# Out:
#         loss       mse       mae  val_loss   val_mse   val_mae  epoch
# 65  0.992346  0.992346  0.701480  0.996576  0.996576  0.702098     65
# 66  0.992452  0.992452  0.700849  0.995619  0.995619  0.706563     66
# 67  0.992787  0.992787  0.700715  0.995917  0.995917  0.704114     67
# 68  0.991919  0.991919  0.701729  0.996010  0.996010  0.703697     68
# 69  0.993086  0.993086  0.703575  0.995577  0.995577  0.708197     69

# %%
# summarize history for Loss

sns.set(rc={'figure.figsize':(6,4)})

plt.plot(fit.history['loss'])
plt.plot(fit.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(fit.history['mse'])
plt.plot(fit.history['val_mse'])
plt.title('model mse')
plt.ylabel('mse')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
